# %% [markdown]
# NLTK has function called Count Vectorizer which can be used to perform Bag of Words
#
# if we have some kind of  text data and suppose we are solving a  sentiment analysis problem statement on that particular text data, we can just  directly give it to my model you know we  need to convert that into some numerical  format we basically called it as **vectors**

# %% [markdown]
# ![06%20Bag%20Of%20Words.PNG](attachment:06%20Bag%20Of%20Words.PNG)

# %% [markdown]
# In the example above we have 3 sentences
#
# always remember during text pre-processing we have to do some things
#
# **first :** of all we need to  lower the sentences because  if we have 'HE' and 'He'  and if I don't lower  the sentence both that particular word  will be denoted in a separate way so it  is always good that you lower the  sentences .
#
# but yes there are some  scenarios like suppose there is  country's  **US** and the word **us** if we lower it then it will be treated same. In  particular case you need you can  actually consider that word in a  separate list and later on you can just  keep that particular words and remaining  all words you can actually lower in the  sentences.
#
# **Second :** we can  apply stemming and lemmatization on the lower sentences. over  here we just taken simple words  stemming a lemmatization is not required in  this particular case but you can do it  because in usual scenario we will be  having so many sentences here we have just  taken an example of three sentences.
#
# **Third :** apply stop words on the sentences so that un importand words are removed. we apply stopwords on our 3 example setences and output is shown on the right

# %% [markdown]
# now we have these three  sentences what we are going to do is we create a histogram  histogram from these three sentences  what does histogram basically mean I  will go and see for each and every word  and I'll just try to find out what is  the frequency. On the lower left of the above picture we see the frequency of the words.
#
# the converetd bag of words table using the sentences are shown in the picture. now We can give this to my machine learning model and can train machine learning model.

# %% [markdown]
# **Disadvantage of bag of words** we have better techniques like tf-idf and word2vector.
#
# the  disadvantage of bag of words now in the  scenario is that my values are either 1 and 0's.  One important thing to note  is that **good value is 1 and boy value as 1** both are having the  equal representation.  the semantics  of this particular words are almost same  we are not able to derive which world is  much more important in sentiment  analysis.
#
# the major thing is that we should know that which word is more  important like in this particular case  good should be important. suppose I take  an example "he is intelligent" over  here intelligent is a major word we need  to try to give more value to that  intelligent word to actually derive a  sentiment analysis.
#
# so that  particular case here you can say either  we are getting ones and zeros these two  words has the same representation right. there's no much more meaning out of it. they are given the equal weight. so this is the major  disadvantage of bag of words and in  order to solve this we basically have  something called as **tf-idf (term frequency and inverse  document frequency)** so we will try to  compute how we can actually find out  term frequency and merge document  frequency by using the same example.
#
# when you are actually doing the  sentiment analysis you can go ahead with  bag of words and try to compute it but  if you have a huge data set please don't  go with bag of words word to vector is the  best way to actually solve with respect  to that.
