# %% [markdown]
# **TF-IDF : Term Frequency - Inverse Document Frequency**
#
# In this we will calculate TF using its formula and then calculate IDF using its formula and the multiply TD with IDF to convert the sentences into vectors.

# %% [markdown]
# in Bag of Words : Our vectors are 1's and o's and the disadvantages is that is no sematic difference between words and all are considered the same.

# %% [markdown]
# ![08%20TF%20IDF.PNG](attachment:08%20TF%20IDF.PNG)
#
# for example we will take the same 3 sentences we used for BOW  and applying stemming/lemmatization and also the stop words are removed.

# %% [markdown]
# * First of all we find out the histograms. Histograms basically means frequency of words in all sentences. (its shown in left botthom of the picture.)
#
# * second we calculate the TF (term frequency). now what does term  frequency actually mean  term frequency is basically given by a  formula **number of repetition of words in  a sentence divided by number of words in a sentence** . with this formula we create the TF table as seen in the picture.
#
# * Third we calculate the IDF using the formula log (No of setences / No of setences containing words). the table on the right shows the values. good exits in all 3 sentences and we have 3 setences hence its log(3/3) = 0 .
#
# * lastly we multiply the TF and IDF for sentences 1 it is 1/2 * 0 , 1/2 * log(3/2), 0 * log(3/2).
